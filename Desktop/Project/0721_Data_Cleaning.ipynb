# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd
import requests
from io import StringIO
import requests
import time
from selenium.webdriver import Chrome
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
import os
from naver_crawler import *
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import parser
from datetime import datetime
from urllib.request import urlopen
import webbrowser

# %%
os.getcwd()
os.chdir('C:\\Users\\shic\\Documents\\GitHub\\Crawling\\Desktop\\Project\\1_Data')

# %%
files = os.listdir(os.getcwd())
for i in files :
    print(i)
# Out:
# DIVIDEND_RANK_2008_2020.csv
# KIND_TODAY_POST_5DAY.csv
# KOREA_CREDIT_1.csv
# KOREA_CREDIT_1_2.csv
# KOREA_CREDIT_2.csv
# KOREA_CREDIT_2_2.csv
# KOREA_CREDIT_3.csv
# KOREA_CREDIT_3_2.csv
# KOREA_CREDIT_4.csv
# KOREA_CREDIT_4_2.csv
# KOREA_CREDIT_5.csv
# KOREA_CREDIT_5_2.csv
# KOREA_CREDIT_6.csv
# KOREA_CREDIT_6_2.csv
# KOREA_CREDIT_7.csv
# KOREA_CREDIT_7_2.csv
# KOREA_CREDIT_8.csv
# KOREA_CREDIT_8_2.csv
# KOREA_VENTURE_FUND_STATUS.csv
# KOREA_VENTURE_FUND_TYPE.csv
# naver_finance_economy_list_summary.csv
# naver_finance_industry_summary.csv
# naver_finance_invest_list_summary.csv
# naver_finance_market_full.csv
# naver_finance_market_summary.csv
# naver_finance_stock_summary.csv
# seibro_dividend_rank_2020.csv
# YOUTUBE_ECO_3PRO.csv
# youtube_eco_3pro_2.csv
# youtube_eco_3pro_5.csv
# youtube_eco_3pro_6.csv
# youtube_eco_3pro_66rows.csv
# youtube_eco_3pro_7.csv
# youtube_eco_3pro_8.csv
# YOUTUBE_ECO_ALL_.csv
# YOUTUBE_ECO_FULL.csv
# youtube_eco_hankyung.csv
# ...

# %% [markdown]
# ## Naver Report : (13518, 12)

# %%
NAVER = pd.read_csv('NAVER_FINANCE_REPORT.csv',dtype=str)
print(NAVER.shape)
NAVER
# Out:
# (13518, 12)
#             Type      date  kapital  \
# 0       Industry  20210714   미래에셋증권
# 1       Industry  20210714     교보증권
# 2       Industry  20210714     교보증권
# 3       Industry  20210714   하나금융투자
# 4       Industry  20210714   하나금융투자
# ...          ...       ...      ...
# 13513  Debenture  20140102    현대차증권
# 13514  Debenture  20131230    현대차증권
# 13515  Debenture  20131223    현대차증권
# 13516  Debenture  20131223  IBK투자증권
# 13517  Debenture  20131223  메리츠종금증권
#
#                                               title            pdf  \
# 0           Global Fintech & Payment : Weekly Brief  1626230372318
# 1                          What's in My Bag: 필수템 찾기  1626229188835
# 2                       건설/부동산 Weekly: 건설 가격 매력 재부각  1626229008434
# 3                휴대폰/부품(Overweight): 6월 중국 스마트폰 출하량  1626228724523
# 4      섬유의복(Overweight): 2Q21 Pre: 2분기 실적 예상보다 좋을 듯  1626228558872
# ...                                             ...            ...
# ...

# %% [markdown]
# ## Youtube : ECO (11119, 7) POP (64, 8)

# %%
# 2020~2021 유튜브 경제 유튜버 제목, 댓글
ECO = pd.read_csv('YOUTUBE_ECO_ALL_.csv',dtype=str)
print(ECO.shape)
ECO
# Out:
# (11119, 7)
#        youtuber                                              title  \
# 0      HANKYUNG  [한상춘의 지금세계는] / 파월 쇼크! 비트코인 3만달러 무너지나? 中 2분기 성장...
# 1      HANKYUNG      美 인플레 우려 지속…투자 전략은? / 유동원의 글로벌 포트폴리오 / 한국경제TV
# 2      HANKYUNG  오늘장 놓쳐선 안 될 당신이 잠든사이 일어난 해외 이슈 6 / 출근전 꼭 봐야하는 ...
# 3      HANKYUNG  메타버스 '숨은 진주' 자회사의 놀라운 기술력 / 최성민의 빅샷+ / 최성민 앵커 ...
# 4      HANKYUNG  EU 저탄소 정책 수혜 신고가 기대되는 2차전지 / 최성민의 빅샷+ / 이상로 와우...
# ...         ...                                                ...
# 11114  KKAKDOKI                 [증시각도기TV] 곽도기의 고객상담: 실전투자 이렇게 하세요!
# 11115  KKAKDOKI            [증시각도기TV] 8월4일 미국마감: 연준, 인플레이션 뚜껑을 열었다!
# 11116  KKAKDOKI                        [증시각도기TV] 주식, 언제 사고 팔아야하나요?
# 11117  KKAKDOKI        [증시각도기TV] 공포의 주식시장에 대응하는 방법(feat.앙드레 코스톨라니)
# 11118  KKAKDOKI                          [증시각도기TV 곽상준]빅테크 폭등과 언텍사회
#
#              date view_num likes_num unlikes_num  \
# 0      2021.7.16.     3318     106.0        22.0
# ...

# %%
ECO.youtuber.value_counts()
# Out:
# HANKYUNG        4474
# 3PRO            3243
# KIMZAKKA        1013
# KKAKDOKI         854
# SHINSAIMDANG     720
# SHUKAWORLD       415
# KIMDANTE         400
# Name: youtuber, dtype: int64

# %%
POP = pd.read_csv('youtube_popular_64rows_0715.csv',dtype=str)
print(POP.shape)
POP
# Out:
# (64, 8)
#                                                  name  \
# 0   BTS: Permission to Dance (TV Debut) | The Toni...
# 1   대한민국 VS 아르헨티나 : 하나은행 초청 올림픽 축구대표팀 평가전 하이라이트 - ...
# 2   [CHOREOGRAPHY] BTS (방탄소년단) 'Permission to Danc...
# 3   BTS Dishes on Touring and Working with Ed Shee...
# 4                  셋이서 의리로 먹는 40인분 비빔유수면🍜 l [미선이네👩‍🍳]
# ..                                                ...
# 59                               생수병과 도어락의 진실 #shorts
# 60  [황태와 양미리 EP.3] 코러스 부탁하러 와서 수족관 먹방 찍고 간 히밥(feat...
# 61  (ENG) 1️⃣처음부터 끝까지 눈을 뗄 수 없는 태연 입덕 레전드 영상 여기서 보...
# 62  첫 방문지 부산🔥 히밥에게 1인분이란..? KCM 지갑 탈탈 털렸습니다 | 떡볶세끼...
# 63  2화) 단독 1등, 고공 행진 보여주는 김준호! 예상치 못한 결과로 충격에 휩싸인 ...
#
#                                                 title                 date  \
# 0   BTS: Permission to Dance (TV Debut) | The Toni...  최초 공개: 2021. 7. 14.
# 1   대한민국 VS 아르헨티나 : 하나은행 초청 올림픽 축구대표팀 평가전 하이라이트 - ...         2021. 7. 13.
# 2   [CHOREOGRAPHY] BTS (방탄소년단) 'Permission to Danc...         2021. 7. 13.
# ...

# %% [markdown]
# ## Dividend : (16611, 11)

# %%
# 2008~2020 배당주 순위
DIV = pd.read_csv('DIVIDEND_RANK_2008_2020.csv',dtype=str)
print(DIV.shape)
DIV
# Out:
# (16611, 11)
#          연도    순위    종목코드                   종목명 주식종류   시장구분   주당배당금   시가배당율  \
# 0      2008     1  072450  리얼티코리아제일호기업구조조정부동산투자  보통주  기타비상장   9,725  195.85
# 1      2008     2  073530    코크렙제3호기업구조조정부동산투자회  보통주  기타비상장  10,891   78.44
# 2      2008     3  089180          동북아28호선박투자회사  보통주  기타비상장       0   55.00
# 3      2008     4  089190          동북아29호선박투자회사  보통주  기타비상장       0   54.90
# 4      2008     5  089200          동북아30호선박투자회사  보통주  기타비상장       0   54.90
# ...     ...   ...     ...                   ...  ...    ...     ...     ...
# 16606  2020  1440  346150                   브이피  보통주  기타비상장     416    0.00
# 16607  2020  1441  302920                 더콘텐츠온  보통주  코넥스시장       0    0.00
# 16608  2020  1442  30709K            케이씨씨오토그룹1우  우선주  기타비상장       0    0.00
# 16609  2020  1443  346150                   브이피  보통주  기타비상장     416    0.00
# 16610  2020  1444  357140              코마스인터렉티브  보통주  기타비상장       0    0.00
#
#        액면가배당율    액면가 결산월
# ...

# %% [markdown]
# ## Post : (1603, 6)

# %%
# 공시정보 최근 5일
POST = pd.read_csv('KIND_TODAY_POST_5DAY.csv',dtype=str)
print(POST.shape)
POST
# Out:
# (1603, 6)
#               일자     시간  시장종류     회사명  \
# 0     2021-07-20  16:32   코스닥     이디티
# 1     2021-07-20  16:32   코스닥     이디티
# 2     2021-07-20  16:32  유가증권    교보증권
# 3     2021-07-20  16:31  유가증권   그린케미칼
# 4     2021-07-20  16:29  유가증권   LX홀딩스
# ...          ...    ...   ...     ...
# 1598  2021-07-16  09:13  유가증권   현대차증권
# 1599  2021-07-16  09:01  유가증권  우리금융지주
# 1600  2021-07-16  09:00  유가증권      한샘
# 1601  2021-07-16  08:40  유가증권  NH투자증권
# 1602  2021-07-16  07:58  유가증권      한샘
#
#                                           공시제목       제출인
# 0                    증권 발행결과(자율공시)(제3자배정 유상증자)       이디티
# 1                  투자판단 관련 주요경영사항(경영지배인 사임의 건)       이디티
# 2                               투자설명서[일괄신고-사채]      교보증권
# 3                                  현금ㆍ현물 배당 결정     그린케미칼
# 4     단기과열종목(가격괴리율, 3거래일 단일가매매) 지정 연장(LX홀딩스1우)  유가증권시장본부
# ...                                        ...       ...
# 1598                     계열금융회사의약관에의한금융거래-[CP]     현대차증권
# ...

# %% [markdown]
# ## Credit : NICE (190057, 22) KOREA (17830, 25) ENTERP

# %%
NICE = pd.read_csv('NICE_CREDIT_ALL.csv',dtype=str)
NICE.shape
# Out:
# (190057, 22)

# %%
NICE
# Out:
#             Type        기업명                       회차    종류  평정     직전등급 직전전망  \
# 0             채권    농협은행(주)      2021-07 외 선순위 무보증사채    SB   본      NaN  NaN
# 1             채권   산은캐피탈(주)                  제671회 외    SB   본      NaN  NaN
# 2             채권     위너콤(주)                        1    SB   본      NaN  NaN
# 3             채권  하나금융투자(주)             제 7-2회 무보증사채    SB   본      NaN  NaN
# 4             채권   메리츠증권(주)  제193회 외 주가연계파생결합사채(ELB)   ELB   본      NaN  NaN
# ...          ...        ...                      ...   ...  ..      ...  ...
# 190052  자산유동화 증권        NaN                     제56회  ABCP  정기  A1 (sf)  NaN
# 190053  자산유동화 증권        NaN                     제57회  ABCP  정기  A1 (sf)  NaN
# 190054  자산유동화 증권        NaN                     제58회  ABCP  정기  A1 (sf)  NaN
# 190055  자산유동화 증권        NaN                     제59회  ABCP  정기  A1 (sf)  NaN
# 190056  자산유동화 증권        NaN                     제60회  ABCP  정기  A1 (sf)  NaN
#
# ...

# %%
KOREA = pd.read_csv('KOREA_CREDIT_ALL.csv',dtype=str)
KOREA.shape
# Out:
# (17830, 25)

# %%
KOREA
# Out:
#                Type      회사명 채권종류        회차 발행액(억원)         만기일 평가종류 직전등급  \
# 0               회사채     모트렉스   PP  7(P-CBO)    80.0         NaN    본  NaN
# 1               회사채     모트렉스   PP  7(P-CBO)    80.0         NaN    본  NaN
# 2               회사채    산은캐피탈   SB       671     NaN         NaN    본  NaN
# 3               회사채    산은캐피탈   SB       671     NaN         NaN    본  NaN
# 4               회사채  우리금융캐피탈   SB       422     NaN         NaN    본  NaN
# ...             ...      ...  ...       ...     ...         ...  ...  ...
# 17825  Covered Bond     국민은행  NaN    2019-5    1500  2024.09.03    본  NaN
# 17826  Covered Bond     국민은행  NaN  2019-4-2    2000  2026.08.14    본  NaN
# 17827  Covered Bond     국민은행  NaN    2019-3    4000  2024.07.23    본  NaN
# 17828  Covered Bond     국민은행  NaN    2019-2    4000  2024.06.25    본  NaN
# 17829  Covered Bond     국민은행  NaN  2019-1-2    1000  2026.05.14    본  NaN
#
#       현재등급         평가일  ... 현재Outlook 기준통화   종류  시리즈   유형 공여기관 한도액(억원) 약정만료일  \
# ...

# %%
ENTERP = pd.read_csv('ENTERPRISE_CREDIT_ALL.csv',dtype=str)
ENTERP.shape

# %%
ENTERP

# %% [markdown]
# ## VENTURE : TYPE (8, 2) STATUS (620, 7)

# %%
VEN1=pd.read_csv('KOREA_VENTURE_FUND_TYPE.csv')
VEN1.shape
# Out:
# (8, 2)

# %%
VEN2=pd.read_csv('KOREA_VENTURE_FUND_STATUS.csv')
VEN2.shape
# Out:
# (620, 7)

# %%
VEN1
# Out:
#    펀드별 코드                 펀드명
# 0      11              한국모태펀드
# 1      12          산업기술사업화모펀드
# 2      13         해외 VC 글로벌펀드
# 3      14            한국전력 모펀드
# 4      15              엔젤 모펀드
# 5      16  KEB하나-KVIC 유니콘 모펀드
# 6      21            엔젤투자매칭펀드
# 7      22             일자리매칭펀드

# %%
VEN2
# Out:
#        년도         출자분야        운용사                          조합명         만기일  \
# 0    2019      LP지분유동화   포스코기술투자㈜           피씨씨-우리 LP지분 유동화 펀드  2027-12-31
# 1    2019       미세먼지해결  ㈜이앤인베스트먼트               2019모태이앤클린에어펀드  2027-12-29
# 2    2019         대학창업  숭실대학교기술지주          숭실대 SUJI 제1호 개인투자조합  2026-12-22
# 3    2019  디지털콘텐츠 해외진출    이에스인베스터             이에스6호디지털콘텐츠글로벌펀드  2026-12-22
# 4    2019      특허기술사업화   퀀텀벤처스코리아             퀀텀5G특화4차산업고급기술펀드  2027-11-27
# ..    ...          ...        ...                          ...         ...
# 615  2007      특허기술사업화   우리인베스트먼트             보스톤특허기술사업화전문투자조합  2013-03-31
# 616  2006         해외진출      엠벤처투자                아시아퍼시픽벤처투자조합B  2014-09-28
# 617  2006         문화산업   미시간벤처캐피탈                미시간글로벌컨텐츠투자조합  2014-06-24
# 618  2006         문화산업   우리인베스트먼트               보스톤영상콘텐츠전문투자조합  2013-12-27
# 619  2005          바이오      인터베스트  인터베스트바이오전문투자조합(한국모태펀드05-01)  2012-10-20
#
#           금액      약정액
# 0    26000.0  10000.0
# ...
