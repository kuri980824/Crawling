# %% [markdown]
# # 한국벤처투자 - 펀드 종류, 현황
# https://www.kvic.or.kr/open/open4_2

# %%
# 벤처산업 활성화 아이디어 공모전 접수 계획 공지
# https://www.kvic.or.kr/notice/notice1_view?category=notice&depth1=1&depth2=6&boardDataNo=3312

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd
import requests
from io import StringIO
import requests
import time
from selenium.webdriver import Chrome
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
import os
from naver_crawler import *
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import parser
import datetime
from urllib.request import urlopen
import webbrowser
import xmltodict
import json
from ast import literal_eval

# %%
os.chdir('C:\\Users\\shic\\Desktop\\Crawling\\Desktop\\Project')
delay=3
browser = Chrome()
browser.implicitly_wait(delay)

API_KEY ='CWIDAfHMQbnkkqBDDKT7'
fund_type_url = "https://www.kvic.or.kr/api/businessType"
url = fund_type_url+"?bType=0&of=1&key="+API_KEY
browser.get(url) # 고급 -> 접속

# %%
result = browser.page_source
soup = BeautifulSoup(result, 'html.parser')
string = soup.get_text()
dictionary = literal_eval(string)
dictionary
# Out:
# {'result': [{'fundCode': '11', 'fundName': '한국모태펀드'},
#   {'fundCode': '12', 'fundName': '산업기술사업화모펀드'},
#   {'fundCode': '13', 'fundName': '해외 VC 글로벌펀드'},
#   {'fundCode': '14', 'fundName': '한국전력 모펀드'},
#   {'fundCode': '15', 'fundName': '엔젤 모펀드'},
#   {'fundCode': '16', 'fundName': 'KEB하나-KVIC 유니콘 모펀드'},
#   {'fundCode': '21', 'fundName': '엔젤투자매칭펀드'},
#   {'fundCode': '22', 'fundName': '일자리매칭펀드'}],
#  'code': ''}

# %%
df1=pd.DataFrame(dictionary['result'])
df1.rename({
    'fundName':'펀드명',
    'fundCode':'펀드별 코드'
},axis=1,inplace=True)
df1
# Out:
#   펀드별 코드                 펀드명
# 0     11              한국모태펀드
# 1     12          산업기술사업화모펀드
# 2     13         해외 VC 글로벌펀드
# 3     14            한국전력 모펀드
# 4     15              엔젤 모펀드
# 5     16  KEB하나-KVIC 유니콘 모펀드
# 6     21            엔젤투자매칭펀드
# 7     22             일자리매칭펀드

# %%
os.chdir('C:\\Users\\shic\\Desktop\\Crawling\\Desktop\\Project\\1_Data')
df1.to_csv('KOREA_VENTURE_FUND_TYPE.csv',index=False)

# %% [markdown]
# ## 펀드 현황 조회

# %%
os.chdir('C:\\Users\\shic\\Desktop\\Crawling\\Desktop\\Project')
delay=3
browser = Chrome()
browser.implicitly_wait(delay)

API_KEY ='CWIDAfHMQbnkkqBDDKT7'
fund_type_url = "https://www.kvic.or.kr/api/fundType"
url = fund_type_url+"?fundType=00&key="+API_KEY
browser.get(url) # 고급 -> 접속

# %%
result = browser.page_source
soup = BeautifulSoup(result, 'html.parser')
string2 = soup.get_text()
dictionary2 = literal_eval(string2)
dictionary2
# Out:
# {'result_11': [{'year': '2019',
#    'fd': 'LP지분유동화',
#    'mng': '포스코기술투자㈜',
#    'asn': '피씨씨-우리 LP지분 유동화 펀드',
#    'exp': '2027-12-31',
#    'amt': '26000',
#    'ca': '10000'},
#   {'year': '2019',
#    'fd': '미세먼지해결',
#    'mng': '㈜이앤인베스트먼트',
#    'asn': '2019모태이앤클린에어펀드',
#    'exp': '2027-12-29',
#    'amt': '21500',
#    'ca': '15000'},
#   {'year': '2019',
#    'fd': '대학창업',
#    'mng': '숭실대학교기술지주',
#    'asn': '숭실대 SUJI 제1호 개인투자조합',
#    'exp': '2026-12-22',
#    'amt': '1700',
#    'ca': '1225'},
#   {'year': '2019',
#    'fd': '디지털콘텐츠 해외진출',
#    'mng': '이에스인베스터',
#    'asn': '이에스6호디지털콘텐츠글로벌펀드',
#    'exp': '2026-12-22',
#    'amt': '15000',
#    'ca': '10500'},
#   {'year': '2019',
#    'fd': '특허기술사업화',
#    'mng': '퀀텀벤처스코리아',
#    'asn': '퀀텀5G특화4차산업고급기술펀드',
#    'exp': '2027-11-27',
#    'amt': '49700',
#    'ca': '2800'},
#   {'year': '2019',
#    'fd': '특허기술사업화',
#    'mng': '유티씨인베스트먼트',
#    'asn': 'KB-UTC 혁신 기술금융 벤처투자조합',
#    'exp': '2027-12-04',
# ...

# %%
df2 = pd.DataFrame(dictionary2['result_11'])
df2.rename({
    'year':'년도',
    'fd':'출자분야',
    'mng':'운용사',
    'asn':'조합명',
    'exp':'만기일',
    'amt':'금액',
    'ca':'약정액'
},axis=1,inplace=True)
df2
# Out:
#        년도         출자분야        운용사                          조합명         만기일  \
# 0    2019      LP지분유동화   포스코기술투자㈜           피씨씨-우리 LP지분 유동화 펀드  2027-12-31
# 1    2019       미세먼지해결  ㈜이앤인베스트먼트               2019모태이앤클린에어펀드  2027-12-29
# 2    2019         대학창업  숭실대학교기술지주          숭실대 SUJI 제1호 개인투자조합  2026-12-22
# 3    2019  디지털콘텐츠 해외진출    이에스인베스터             이에스6호디지털콘텐츠글로벌펀드  2026-12-22
# 4    2019      특허기술사업화   퀀텀벤처스코리아             퀀텀5G특화4차산업고급기술펀드  2027-11-27
# ..    ...          ...        ...                          ...         ...
# 615  2007      특허기술사업화   우리인베스트먼트             보스톤특허기술사업화전문투자조합  2013-03-31
# 616  2006         해외진출      엠벤처투자                아시아퍼시픽벤처투자조합B  2014-09-28
# 617  2006         문화산업   미시간벤처캐피탈                미시간글로벌컨텐츠투자조합  2014-06-24
# 618  2006         문화산업   우리인베스트먼트               보스톤영상콘텐츠전문투자조합  2013-12-27
# 619  2005          바이오      인터베스트  인터베스트바이오전문투자조합(한국모태펀드05-01)  2012-10-20
#
#         금액      약정액
# 0    26000    10000
# 1    21500    15000
# ...

# %%
os.chdir('C:\\Users\\shic\\Desktop\\Crawling\\Desktop\\Project\\1_Data')
df2.to_csv('KOREA_VENTURE_FUND_STATUS.csv',index=False)
