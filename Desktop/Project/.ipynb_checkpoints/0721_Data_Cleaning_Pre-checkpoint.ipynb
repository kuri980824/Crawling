# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd
import requests
from io import StringIO
import requests
import time
from selenium.webdriver import Chrome
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
import os
from naver_crawler import *
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re
import parser
from datetime import datetime
from urllib.request import urlopen
import webbrowser

# %%
os.getcwd()
os.chdir('C:\\Users\\shic\\Documents\\GitHub\\Crawling\\Desktop\\Project\\1_Data')

# %%
files = os.listdir(os.getcwd())
for i in files :
    print(i)
# Out:
# DIVIDEND_RANK_2008_2020.csv
# KIND_TODAY_POST_5DAY.csv
# KOREA_CREDIT_1.csv
# KOREA_CREDIT_1_2.csv
# KOREA_CREDIT_2.csv
# KOREA_CREDIT_2_2.csv
# KOREA_CREDIT_3.csv
# KOREA_CREDIT_3_2.csv
# KOREA_CREDIT_4.csv
# KOREA_CREDIT_4_2.csv
# KOREA_CREDIT_5.csv
# KOREA_CREDIT_5_2.csv
# KOREA_CREDIT_6.csv
# KOREA_CREDIT_6_2.csv
# KOREA_CREDIT_7.csv
# KOREA_CREDIT_7_2.csv
# KOREA_CREDIT_8.csv
# KOREA_CREDIT_8_2.csv
# KOREA_VENTURE_FUND_STATUS.csv
# KOREA_VENTURE_FUND_TYPE.csv
# naver_finance_economy_list_summary.csv
# naver_finance_industry_summary.csv
# naver_finance_invest_list_summary.csv
# naver_finance_market_full.csv
# naver_finance_market_summary.csv
# naver_finance_stock_summary.csv
# seibro_dividend_rank_2020.csv
# YOUTUBE_ECO_3PRO.csv
# youtube_eco_3pro_2.csv
# youtube_eco_3pro_5.csv
# youtube_eco_3pro_6.csv
# youtube_eco_3pro_66rows.csv
# youtube_eco_3pro_7.csv
# youtube_eco_3pro_8.csv
# YOUTUBE_ECO_ALL_.csv
# YOUTUBE_ECO_FULL.csv
# youtube_eco_hankyung.csv
# YOUTUBE_ECO_HANKYUNG_.csv
# youtube_eco_hankyung_2.csv
# youtube_eco_hankyung_3.csv
# youtube_eco_hankyung_4.csv
# youtube_eco_hankyung_8.csv
# YOUTUBE_ECO_HANKYUNG_FULL.csv
# youtube_eco_kimdante.csv
# YOUTUBE_ECO_KIMDANTE_.csv
# youtube_eco_kimzakka.csv
# YOUTUBE_ECO_KIMZAKKA_.csv
# youtube_eco_kimzakka_1.csv
# YOUTUBE_ECO_KKAKDOKI.csv
# youtube_eco_kkakdoki_1.csv
# youtube_eco_kkakdoki_2.csv
# youtube_eco_shinsa.csv
# YOUTUBE_ECO_SHINSAIMDANG.csv
# youtube_eco_shinsa_3.csv
# youtube_eco_shinsa_4.csv
# youtube_eco_shinsa_5.csv
# youtube_eco_shinsa_6.csv
# youtube_eco_shinsa_7.csv
# youtube_eco_shinsa_8.csv
# youtube_eco_shuka.csv
# 11117  http://www.youtube.com/watch?v=G5gt060P22A    13084      1337
# 11118  http://www.youtube.com/watch?v=27vRl81uQso    19392      1763
#
#       unlikes_num                                           comments  youtuber
# 0              22                                                NaN  HANKYUNG
# 1               4  김작가 TV를 통해 유동원님 알게되어서 꾸준히 챙겨볼려고 노력중인데요~~!! 불사조...  HANKYUNG
# 2              30  좋은 뉴스 감사합니다. 한주 동안 수고하셨습니다.|5:49 꺄끄 눈나 😍😍|이제 빨...  HANKYUNG
# 3              14  넵튠 소개하는데 크래프톤을 1도 언급안하다니.. 작전 공조 세력인가 최성민 아저씨....  HANKYUNG
# 4             NaN  고려아연\r\n유럽연합 부문별 탄소감축정책 발표 예정\r\n양극재용 황산니켈 제조생...  HANKYUNG
# ...           ...                                                ...       ...
# 11114           6                                                NaN  KKAKDOKI
# 11115           7                                                NaN  KKAKDOKI
# 11116           6                                                NaN  KKAKDOKI
# 11117           6                                                NaN  KKAKDOKI
# 11118           9                                                NaN  KKAKDOKI
#
# [11119 rows x 9 columns]

# %%
ECO.youtuber.value_counts()
# Out:
# HANKYUNG        4474
# 3PRO            3243
# KIMZAKKA        1013
# KKAKDOKI         854
# SHINSAIMDANG     720
# SHUKAWORLD       415
# KIMDANTE         400
# Name: youtuber, dtype: int64

# %%
# 2008~2020 배당주 순위
DIV = pd.read_csv('DIVIDEND_RANK_2008_2020.csv',dtype=str)
print(DIV.shape)
DIV
# Out:
# (16611, 11)
#          연도    순위    종목코드                   종목명 주식종류   시장구분   주당배당금   시가배당율  \
# 0      2008     1  072450  리얼티코리아제일호기업구조조정부동산투자  보통주  기타비상장   9,725  195.85
# 1      2008     2  073530    코크렙제3호기업구조조정부동산투자회  보통주  기타비상장  10,891   78.44
# 2      2008     3  089180          동북아28호선박투자회사  보통주  기타비상장       0   55.00
# 3      2008     4  089190          동북아29호선박투자회사  보통주  기타비상장       0   54.90
# 4      2008     5  089200          동북아30호선박투자회사  보통주  기타비상장       0   54.90
# ...     ...   ...     ...                   ...  ...    ...     ...     ...
# 16606  2020  1440  346150                   브이피  보통주  기타비상장     416    0.00
# 16607  2020  1441  302920                 더콘텐츠온  보통주  코넥스시장       0    0.00
# 16608  2020  1442  30709K            케이씨씨오토그룹1우  우선주  기타비상장       0    0.00
# 16609  2020  1443  346150                   브이피  보통주  기타비상장     416    0.00
# 16610  2020  1444  357140              코마스인터렉티브  보통주  기타비상장       0    0.00
#
#        액면가배당율    액면가 결산월
# 0      196.68  5,000  04
# 1      318.45  5,000  05
# 2       83.97  5,000  12
# 3       83.97  5,000  12
# 4       83.97  5,000  12
# ...       ...    ...  ..
# 16606    8.32  5,000  12
# 16607    0.00    500  12
# 16608   20.00    500  12
# 16609    8.32  5,000  12
# 16610   13.00    500  12
#
# [16611 rows x 11 columns]

# %%
# 공시정보 최근 5일
POST = pd.read_csv('KIND_TODAY_POST_5DAY.csv',dtype=str)
print(POST.shape)
POST
# Out:
# (1603, 6)
#               일자     시간  시장종류     회사명  \
# 0     2021-07-20  16:32   코스닥     이디티
# 1     2021-07-20  16:32   코스닥     이디티
# 2     2021-07-20  16:32  유가증권    교보증권
# 3     2021-07-20  16:31  유가증권   그린케미칼
# 4     2021-07-20  16:29  유가증권   LX홀딩스
# ...          ...    ...   ...     ...
# 1598  2021-07-16  09:13  유가증권   현대차증권
# 1599  2021-07-16  09:01  유가증권  우리금융지주
# 1600  2021-07-16  09:00  유가증권      한샘
# 1601  2021-07-16  08:40  유가증권  NH투자증권
# 1602  2021-07-16  07:58  유가증권      한샘
#
#                                           공시제목       제출인
# 0                    증권 발행결과(자율공시)(제3자배정 유상증자)       이디티
# 1                  투자판단 관련 주요경영사항(경영지배인 사임의 건)       이디티
# 2                               투자설명서[일괄신고-사채]      교보증권
# 3                                  현금ㆍ현물 배당 결정     그린케미칼
# 4     단기과열종목(가격괴리율, 3거래일 단일가매매) 지정 연장(LX홀딩스1우)  유가증권시장본부
# ...                                        ...       ...
# 1598                     계열금융회사의약관에의한금융거래-[CP]     현대차증권
# 1599                                     투자설명서    우리금융지주
# 1600                주식선물 2단계 가격제한폭 확대요건 도달(상승)  파생상품시장본부
# 1601                                 증권발행실적보고서  엔에이치투자증권
# 1602                         조회공시 요구(풍문 또는 보도)  유가증권시장본부
#
# [1603 rows x 6 columns]

# %%
files = os.listdir(os.getcwd())
for i in files :
    print(i)
# Out:
# DIVIDEND_RANK_2008_2020.csv
# KIND_TODAY_POST_5DAY.csv
# KOREA_CREDIT_1.csv
# KOREA_CREDIT_1_2.csv
# KOREA_CREDIT_2.csv
# KOREA_CREDIT_2_2.csv
# KOREA_CREDIT_3.csv
# KOREA_CREDIT_3_2.csv
# KOREA_CREDIT_4.csv
# KOREA_CREDIT_4_2.csv
# KOREA_CREDIT_5.csv
# KOREA_CREDIT_5_2.csv
# KOREA_CREDIT_6.csv
# KOREA_CREDIT_6_2.csv
# KOREA_CREDIT_7.csv
# KOREA_CREDIT_7_2.csv
# KOREA_CREDIT_8.csv
# KOREA_CREDIT_8_2.csv
# KOREA_VENTURE_FUND_STATUS.csv
# KOREA_VENTURE_FUND_TYPE.csv
# naver_finance_economy_list_summary.csv
# naver_finance_industry_summary.csv
# naver_finance_invest_list_summary.csv
# naver_finance_market_full.csv
# naver_finance_market_summary.csv
# naver_finance_stock_summary.csv
# seibro_dividend_rank_2020.csv
# YOUTUBE_ECO_3PRO.csv
# youtube_eco_3pro_2.csv
# youtube_eco_3pro_5.csv
# youtube_eco_3pro_6.csv
# youtube_eco_3pro_66rows.csv
# youtube_eco_3pro_7.csv
# youtube_eco_3pro_8.csv
# YOUTUBE_ECO_ALL_.csv
# YOUTUBE_ECO_FULL.csv
# youtube_eco_hankyung.csv
# YOUTUBE_ECO_HANKYUNG_.csv
# youtube_eco_hankyung_2.csv
# youtube_eco_hankyung_3.csv
# youtube_eco_hankyung_4.csv
# youtube_eco_hankyung_8.csv
# YOUTUBE_ECO_HANKYUNG_FULL.csv
# youtube_eco_kimdante.csv
# YOUTUBE_ECO_KIMDANTE_.csv
# youtube_eco_kimzakka.csv
# YOUTUBE_ECO_KIMZAKKA_.csv
# youtube_eco_kimzakka_1.csv
# YOUTUBE_ECO_KKAKDOKI.csv
# youtube_eco_kkakdoki_1.csv
# youtube_eco_kkakdoki_2.csv
# youtube_eco_shinsa.csv
# YOUTUBE_ECO_SHINSAIMDANG.csv
# youtube_eco_shinsa_3.csv
# youtube_eco_shinsa_4.csv
# youtube_eco_shinsa_5.csv
# youtube_eco_shinsa_6.csv
# youtube_eco_shinsa_7.csv
# youtube_eco_shinsa_8.csv
# youtube_eco_shuka.csv
# YOUTUBE_ECO_SHUKAWORLD.csv
# youtube_popular_64rows_0715.csv

# %%
CREDIT1 = pd.read_csv('KOREA_CREDIT_1.csv',dtype=str)
CREDIT1
# Out:
#            회사명 채권종류         회차 발행액(억원)         만기일 평가종류 직전등급 현재등급         평가일  \
# 0         모트렉스   PP   7(P-CBO)    80.0         NaN    본  NaN  BB-  2021.07.19
# 1         모트렉스   PP   7(P-CBO)    80.0         NaN    본  NaN  안정적  2021.07.19
# 2        산은캐피탈   SB        671     NaN         NaN    본  NaN  AA-  2021.07.19
# 3        산은캐피탈   SB        671     NaN         NaN    본  NaN  안정적  2021.07.19
# 4      우리금융캐피탈   SB        422     NaN         NaN    본  NaN  AA-  2021.07.19
# ...        ...  ...        ...     ...         ...  ...  ...  ...         ...
# 11615     신한은행   SB  11-05단15A     100  2022.05.02   정기  안정적  안정적  2010.04.30
# 11616     신한은행   HB      신한은행1    2225  2034.10.28   정기   AA   AA  2010.04.30
# 11617     신한은행   HB      신한은행1    2225  2034.10.28   정기  안정적  안정적  2010.04.30
# 11618  한국수력원자력   SB        9-2     700  2029.10.16   정기  AAA  AAA  2010.04.16
# 11619  한국수력원자력   SB        9-2     700  2029.10.16   정기  안정적  안정적  2010.04.16
#
#        리포트 Type
# 0        S  회사채
# 1        S  회사채
# 2        S  회사채
# 3        S  회사채
# 4        S  회사채
# ...    ...  ...
# 11615  S R  회사채
# 11616  S R  회사채
# 11617  S R  회사채
# 11618  S R  회사채
# 11619  S R  회사채
#
# [11620 rows x 11 columns]

# %%
CREDIT1_1 = pd.read_csv('KOREA_CREDIT_1.csv',dtype=str)
CREDIT
