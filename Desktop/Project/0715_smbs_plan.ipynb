# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd
import requests
from io import StringIO
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
import os
from naver_crawler import *

# %%
os.chdir('C:\\Users\\shic\\Desktop\\Project')

# %%
text = read_pdf_PDFMINER('(홈페이지)중소기업_육성_종합계획(2020년_2022년).pdf')

# %%
from konlpy.tag import Hannanum
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-0b2f789dacbb> in <module>
# ----> 1 from konlpy.tag import Hannanum
#
# ModuleNotFoundError: No module named 'konlpy'

# %%
import sys 
print("--sys.version—")
print(sys.version)
# Out:
# --sys.version—
# 3.8.10 (default, May 19 2021, 13:12:57) [MSC v.1916 64 bit (AMD64)]

# %%
# !pip install wheel
# Out:
# Requirement already satisfied: wheel in c:\users\shic\anaconda3\envs\gy\lib\site-packages (0.36.2)

# %%
# Out:
# Requirement already satisfied: pip in c:\users\shic\anaconda3\envs\gy\lib\site-packages (21.1.3)
# Processing c:\users\shic\desktop\project\jpype1-1.1.2-cp38-cp38-win_amd64.whl
# JPype1 is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
java_home = 'C:\Program Files\Java\jdk-16.0.1'

# %%
--force-reinstall JPype1-1.1.2-cp38-cp38-win_amd64.whl
# Out:
#   File "<ipython-input-13-5605a9c86943>", line 1
#     --force-reinstall JPype1-1.1.2-cp38-cp38-win_amd64.whl
#                       ^
# SyntaxError: invalid syntax

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)'))': /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)'))': /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)'))': /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)'))': /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)'))': /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Max retries exceeded with url: /packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1131)')))

# %%
text.replace('\n','')
# Out:
# "중소기업  육성  종합계획(2020중소기업 중소기업 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 육성 종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획종합계획중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 중소기업 (2020년∼2022년)(2020년년년년년년년년년년년년년년∼∼∼∼∼∼∼∼∼∼∼∼∼∼20222022202220222022202220222022202220222022202220222022년년년년년년년년년년년년년년))))))))))))))(2020(2020(2020(2020(2020(2020(2020(2020(2020(2020(2020(2020-  글로벌  혁신기업  육성을  통한  디지털강국  구현 --------------- - - - - - - - - - - - - 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 글로벌 혁신기업 디지털강국 구현구현구현구현구현구현구현구현구현구현구현구현구현혁신기업 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 육성을 통한 통한 통한 통한 통한 통한 통한 통한 통한 통한 통한 통한 통한 디지털강국 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 디지털강국 혁신기업 2020. 9.대 한 민 국 정 부\x0c목    차Ⅰ.  수립배경  및  의미 ·······················································  1Ⅱ.  그간의  정책  추진성과 ··············································  2Ⅲ.  정책  추진여건 ···························································  15Ⅳ.  코로나19  -  중소·벤처·소상공인  여건 ············· 19Ⅴ.  향후  정책방향 ···························································  26Ⅵ. 중소기업  육성  종합계획(2020년∼2022년) ······  28Ⅶ.  기대효과 ······································································  80\x0cⅠ.  수립배경  및  의미□ (배경) 문재인 정부 출범과 함께, 우리 경제의 중심을 중소·벤처·소상공인으로 전환하기 위해 ’중소벤처기업부‘를 신설(’17.7월)          *  1960년  상공부  중소기업과로  출발한지  57년,  중소기업청이  개청한지  21년만의  일ㅇ  중소·벤처·소상공인에 대한 체계적 육성을 위해 ’중소기업 육성에관한 종합계획‘ 수립 근거도 마련(중소기업기본법 개정)□ (추진경과) 그 간 중소기업 육성 종합계획 수립을 위해 중장기 전략연구, 폭넓은 현장의 목소리 청취, 유관기관 의견수렴 등 진행ㅇ  특히, 국력을 결집해 추진하는 ‘한국판 뉴딜’ 프로젝트 중, 중소·벤처·소상공인 관련 정책과제와 추진계획을 반영(’20.7∼8월)➊  (중장기  전략  연구)  대·내외  환경  분석,  중장기  정책과제  도출,  정책의  방향성 검토  등을  위한  전문  연구용역  추진(’19.5∼12월,  중소기업연구원)➋  (현장의  목소리  청취)  중소·벤처·소상공인  협·단체와의  간담회,  기업  현장방문  등 전방위로  현장의  의견을  청취(‘20.1∼7월,  194회  추진)      * 현장방문 34회, 간담회 24회, 중소·벤처·소상공인 정책 소통행사 76회, 언론소통 60회 등➌  (유관기관  의견수렴)  현장에서  중소·벤처·소상공인  정책을  집행하는  유관기관과 정책토론회 등 개최(’20.1∼7월, 34회, 14개 기관) → 다양한 제도 개선과제 발굴□ (대책의 의미) 코로나19 위기 극복을 위해 소상공인 경영안정 및위기 중소기업 지원체계를 구축하고,ㅇ 세계 경제의 디지털 경제로의 전환에 맞는 새로운 중소·벤처·소상공인 육성 전략을 마련ㅇ 또한, 굴뚝 제조공장 등 전통 중소기업 및 소상공인·전통시장의경쟁력 제고를 위한 맞춤형 지원시책을 강화◇  「중소기업  육성  종합계획(2020년∼2022년)」을  통해  글로벌 혁신기업을  육성하여  세계를  선도하는  디지털강국  구현-  1  -\x0cⅡ.  그간의  정책  추진성과◇  중기부  1기(~’20.8)  :  정책  추진의  토대를  마련하고,  ‘디지털  경제로의 대전환,  스마트  대한민국’을  새로운  목표로  설정하고  정책을  설계\uf000‘디지털  경제로의  대전환,  스마트  대한민국’추진기반  구축· 스마트공장(3만개) 로드맵 수립(’18.12), AI·데이터 기반 제조혁신고도화 기반 마련(’20.7), 투자형･후불형 R&D 제도 신설(’20.7) 등 추진· 중기부의 예산 체계를 스마트공장·상점·서비스 등 디지털 전환을 촉진하는 방식으로 개편하고, 비대면·온라인경제 전담조직 등 신설(‘20)\uf000  벤처  일자리  창출,  사상  최대  벤처투자  등  제2벤처  붐  실현· 최대 규모의 벤처기업 일자리(’20.상, 66.8만명)로 고용의 축 변화(대기업중심 → 벤처·스타트업), 역대 최대 벤처투자(’19. 4.3조원), 유니콘기업(’19. 11개, 세계 6위) 등 성과 시현· 규제자유특구 지정(21개), 벤처투자촉진법 제정(’20.8 시행), 비대면‧디지털 전용펀드 신설(’20.7, “스마트대한민국펀드”) 등 혁신 기반 구축\uf000  소상공인·자영업을  독립된 정책영역으로 육성,  자생력 있는  생태계 조성· ‘소상공인기본법’ 제정(’21.2 시행), 간편결제시스템 도입(‘20.7, 결제액5천억), 온누리·지역사랑상품권 활성화 등을 통한 자생력 제고 지원· 국민과 함께한 ’크리스마스마켓‘(’19.12), ‘대한민국 동행세일’(’20.6)을통한 비대면 라이브 방식의 ‘K-세일’ 영역 구축 등 활성화 기반 마련\uf000  자상한  기업  등  민간이  선도하는  상생협력  문화  확산· 자상한 기업 상생협력 MOU 체결(17회), 생계형 적합업종, 상생결제액 100조원 돌파 등으로 자발적 상생협력 문화 확산· 상생조정위원회(’19.6 출범)를 통한 상생조정(11건), 골목상권 보호제도 확충, 기술탈취 근절 협업체계 구축 등 불공정거래 근절\uf000  국가대표  ‘브랜드K’  및  소부장  기업  육성을  통한  경쟁력  강화· ‘브랜드K’ 런칭(’19.9) 및 총 120개 제품 선정(1기 39개, 2기 81개),‘브랜드K 확산 전략(’20.3)’ 수립 및 전략적 마케팅으로 매출·수출 증가· 국민참여 방식의 소부장 강소기업100 선정, 사회 환원 시스템 구축(함께 성장 마중물 협약식) 및 대-중소 간 분업적 협력체계의 상생모델 발굴-  2  -\x0c1   ‘디지털  경제로의  대전환,  스마트  대한민국’  추진기반  구축□ 스마트공장 도입을 통한 굴뚝 제조공장 - 전통 중소기업 경쟁력 제고ㅇ「중소기업 스마트 제조혁신 전략」(’18.12월)에 따라, 15,109개를보급(’20.7월, 누적), ’22년까지 3만개 보급 추진 중          *  스마트공장  로드맵  :  (‘19)  12,660  →  (’20)  17,800  →  (‘21)  23,800  →  (’22)  30,000  수작업  품질검사  스마트화로  재해율  0%  달성   ·  볼트･너트  표면처리  후  수작업으로  진행하던  품질검사를  다관절  로봇사  례으로  대체하고,  MES  구축으로  공정･물류를  데이터화  ·  수작업  품질검사에서  작업자의  안전사고가  발생해  왔으나,  이후  위험한 작업은  로봇을  활용하여  재해율  0%  달성ㅇ 전통 중소 제조기업의 스마트공장 도입을 통해 생산성 등 경쟁력향상*, 고용 창출 및 매출·수출·고용유지 성과 실현   ...
